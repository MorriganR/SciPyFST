# %%
from devSciPyFST import fst, fstUtils
from examples_data.MealyFST import mealyFSTmap as mealyFSTmap
import graphviz, wavedrom
from IPython.display import display, Markdown

# %% [markdown]
# Test #01

# %%
init = mealyFSTmap['test01']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
print(fstUtils.toTexTable(fstMealy))
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# \begin{tabular}{|c||c|c|c|c|}
#  \hline
#  \multirow{2}{*}{Input} &
#  \multicolumn{4}{c|}{State} \\ \cline{2-5}
#  & S0 & S1 & S2 & S3 \\ \hline\hline
#  x1 & S3/y1 & S0/y2 & S2/y3 & S0/y5 \\ \hline
#  x2 & S1/y1 & S2/y1 & S0/y4 & S3/y2 \\ \hline
#  x3 & S0/y5 & S1/y4 & S3/y1 & S1/y5 \\ \hline
# \end{tabular}
# | Input \ State | S0 | S1 | S2 | S3 |
# |:---:|:---:|:---:|:---:|:---:|
# | x1 | S3/y1 | S0/y2 | S2/y3 | S0/y5 |
# | x2 | S1/y1 | S2/y1 | S0/y4 | S3/y2 |
# | x3 | S0/y5 | S1/y4 | S3/y1 | S1/y5 |

# %%
fstMoore = fstMealy.asMoore()
print(fstUtils.toTexTable(fstMoore))
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# \begin{tabular}{|c||c|c|c|c|c|c|c|c|c|c|c|}
#  \hline
#  \multirow{2}{*}{Input} &
#  \multicolumn{11}{c|}{State} \\ \cline{2-12}
#  & 0/- & 1/y1 & 2/y1 & 3/y5 & 4/y2 & 8/y4 & 9/y2 & 10/y5 & 5/y1 & 6/y4 & 7/y3 \\ \hline\hline
#  x1 & 1 & 3 & 4 & 1 & 1 & 1 & 3 & 4 & 7 & 4 & 7 \\ \hline
#  x2 & 2 & 9 & 5 & 2 & 2 & 2 & 9 & 5 & 8 & 5 & 8 \\ \hline
#  x3 & 3 & 10 & 6 & 3 & 3 & 3 & 10 & 6 & 1 & 6 & 1 \\ \hline
# \end{tabular}
# | Input \ State | 0/- | 1/y1 | 2/y1 | 3/y5 | 4/y2 | 8/y4 | 9/y2 | 10/y5 | 5/y1 | 6/y4 | 7/y3 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 3 | 4 | 1 | 1 | 1 | 3 | 4 | 7 | 4 | 7 |
# | x2 | 2 | 9 | 5 | 2 | 2 | 2 | 9 | 5 | 8 | 5 | 8 |
# | x3 | 3 | 10 | 6 | 3 | 3 | 3 | 10 | 6 | 1 | 6 | 1 |

# %% [markdown]
# Test #02

# %%
init = mealyFSTmap['test02']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | S0 | S1 | S2 |
# |:---:|:---:|:---:|:---:|
# | x1 | S2/y2 | S0/y1 | S1/y2 |
# | x2 | S1/y1 | S2/y3 | S0/y1 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/y2 | 2/y1 | 3/y1 | 5/y2 | 4/y3 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 5 | 3 | 1 | 3 | 5 |
# | x2 | 2 | 3 | 4 | 2 | 4 | 3 |

# %% [markdown]
# Test #03

# %%
init = mealyFSTmap['test03']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | A0 | A1 | A2 | A3 |
# |:---:|:---:|:---:|:---:|:---:|
# | x1 | A2/y1 | A2/y2 | A1/y3 | A2/y3 |
# | x2 | A3/y1 | A3/y2 | A3/y1 | A3/y2 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/y1 | 2/y1 | 5/y3 | 3/y2 | 6/y3 | 4/y2 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 5 | 6 | 3 | 5 | 5 | 6 |
# | x2 | 2 | 2 | 4 | 4 | 2 | 2 | 4 |

# %% [markdown]
# test #04

# %%
init = mealyFSTmap['test04']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | A0 | A1 | A2 | A3 | A4 |
# |:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | A4/y1 | A2/y1 | A1/y1 | A3/y2 | A3/y2 |
# | x2 | A2/y1 | A4/y1 | A2/y1 | A2/y1 | A2/y1 |
# | x3 | A3/y2 | A3/y2 | A3/y2 | A4/y1 | A1/y1 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/y1 | 2/y1 | 3/y2 | 4/y1 |
# |:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 3 | 4 | 3 | 2 |
# | x2 | 2 | 2 | 2 | 2 | 1 |
# | x3 | 3 | 4 | 3 | 1 | 3 |

# %% [markdown]
# Test #05

# %%
init = mealyFSTmap['test05']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | a1 | a2 | a3 |
# |:---:|:---:|:---:|:---:|
# | z1 | a3/w1 | a1/w1 | a1/w2 |
# | z2 | a1/w1 | a3/w2 | a2/w1 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/w1 | 2/w1 | 4/w2 | 5/w1 | 3/w2 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | z1 | 1 | 4 | 1 | 1 | 2 | 4 |
# | z2 | 2 | 5 | 2 | 2 | 3 | 5 |

# %% [markdown]
# Test #06

# %%
init = mealyFSTmap['test06']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | a1 | a2 | a3 | a4 |
# |:---:|:---:|:---:|:---:|:---:|
# | z1 | a2/w1 | a3/w3 | a4/w3 | -/- |
# | z2 | a3/w2 | -/- | a2/w1 | a2/w2 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/w1 | 2/w2 | 3/w3 | 4/- | 6/w2 | 5/w3 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | z1 | 1 | 3 | 5 | 5 | - | 3 | 4 |
# | z2 | 2 | 4 | 1 | 1 | - | 4 | 6 |

# %% [markdown]
# Test #07

# %%
init = mealyFSTmap['test07']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | Q1 | Q2 | Q3 | Q4 |
# |:---:|:---:|:---:|:---:|:---:|
# | x1 | Q2/y1 | Q1/y2 | Q1/y1 | Q4/y2 |
# | x2 | Q4/y1 | Q3/y1 | Q4/y2 | Q1/y1 |
# | x3 | Q1/y2 | Q4/y1 | Q2/y2 | Q3/y1 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/y1 | 2/y1 | 3/y2 | 5/y1 | 4/y1 | 7/y2 | 6/y2 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 3 | 6 | 1 | 1 | 5 | 3 | 6 |
# | x2 | 2 | 4 | 5 | 2 | 2 | 6 | 4 | 5 |
# | x3 | 3 | 2 | 4 | 3 | 3 | 7 | 2 | 4 |

# %% [markdown]
# Test #08

# %%
init = mealyFSTmap['test08']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | Q1 | Q2 | Q3 | Q4 | Q5 |
# |:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | Q2/y1 | Q3/y2 | -/- | Q1/y2 | Q3/y2 |
# | x2 | Q1/y2 | Q5/y1 | Q3/y2 | Q3/y1 | Q1/y1 |
# | x3 | -/- | Q4/y2 | -/- | Q4/y2 | Q5/y1 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/y1 | 2/y2 | 3/- | 8/y1 | 4/y2 | 5/y1 | 6/y2 | 7/y1 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 4 | 1 | - | 1 | 3 | 4 | 2 | 3 |
# | x2 | 2 | 5 | 2 | - | 2 | 4 | 8 | 7 | 4 |
# | x3 | 3 | 6 | 3 | - | 3 | 3 | 5 | 6 | 3 |

# %% [markdown]
# Test #09

# %%
init = mealyFSTmap['test09']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | Q1 | Q2 | Q3 | Q4 | Q5 | Q6 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | Q1/y3 | Q5/y3 | Q4/y3 | Q5/y1 | Q5/y1 | Q1/y2 |
# | x2 | Q2/y1 | Q3/y2 | Q3/y2 | Q4/y3 | Q3/y1 | Q5/y1 |
# | x3 | Q4/y3 | Q2/y2 | Q3/y1 | Q4/y1 | Q2/y3 | Q3/y2 |
# | x4 | Q6/y1 | Q6/y1 | Q5/y1 | Q4/y2 | Q6/y2 | Q6/y2 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/y3 | 2/y1 | 3/y3 | 4/y1 | 14/y2 | 5/y3 | 6/y2 | 7/y2 | 12/y3 | 9/y1 | 10/y1 | 11/y2 | 13/y2 | 8/y1 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 1 | 5 | 9 | 14 | 1 | 9 | 3 | 5 | 5 | 9 | 9 | 9 | 14 | 3 |
# | x2 | 2 | 2 | 6 | 3 | 9 | 2 | 8 | 6 | 6 | 6 | 8 | 3 | 3 | 9 | 6 |
# | x3 | 3 | 3 | 7 | 10 | 6 | 3 | 12 | 8 | 7 | 7 | 12 | 10 | 10 | 6 | 8 |
# | x4 | 4 | 4 | 4 | 11 | 13 | 4 | 13 | 9 | 4 | 4 | 13 | 11 | 11 | 13 | 9 |

# %% [markdown]
# Test #10

# %%
init = mealyFSTmap['test10']
fstMealy = fst(init[0], init[1], init[2], init[3], init[4], init[5])
display(Markdown(fstUtils.toMdTable(fstMealy)))
display(graphviz.Source(fstUtils.toDot(fstMealy)))
# Out:
# | Input \ State | Q1 | Q2 | Q3 | Q4 |
# |:---:|:---:|:---:|:---:|:---:|
# | x1 | Q2/y2 | Q1/y1 | Q1/y1 | Q4/y2 |
# | x2 | Q4/y1 | Q3/y2 | Q4/y1 | Q1/y1 |
# | x3 | Q1/y2 | Q4/y1 | Q2/y1 | Q3/y2 |

# %%
fstMoore = fstMealy.asMoore()
display(Markdown(fstUtils.toMdTable(fstMoore)))
display(graphviz.Source(fstUtils.toDot(fstMoore)))
# Out:
# | Input \ State | 0/- | 1/y2 | 2/y1 | 3/y2 | 4/y1 | 5/y2 | 6/y1 | 7/y2 |
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# | x1 | 1 | 4 | 7 | 1 | 1 | 4 | 4 | 7 |
# | x2 | 2 | 5 | 4 | 2 | 2 | 2 | 5 | 4 |
# | x3 | 3 | 2 | 5 | 3 | 3 | 6 | 2 | 5 |
